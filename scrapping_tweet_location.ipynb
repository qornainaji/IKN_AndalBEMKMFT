# %% [markdown]
# # Scraping

# %% [markdown]
# Pada bagian ini, kita akan melakukan scraping menggunakan **Twint** yang tidak memerlukan akun *developer* dalam melakukan *scraping*

# %%
# !pip install git+https://github.com/karuniaperjuangan/twint
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/karuniaperjuangan/twint to /tmp/pip-req-build-gdy19d84
#   Running command git clone -q https://github.com/karuniaperjuangan/twint /tmp/pip-req-build-gdy19d84
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-cpt9xaba
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-cpt9xaba
# ...
# ERROR: Package 'snscrape' requires a different Python: 3.7.13 not in '~=3.8'

# %%
import twint # coba pakai library yang baru saja diinstal
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# Sekarang kita akan membuat perintah untuk scraping

# %%
# c = twint.Config()

# c.Search = "ibu kota negara"
# c.Geo = "-7.277028, 109.870750, 150km"
# c.Lang = "id"
# c.Since = "2021-01-01"
# c.Until = "2022-06-21"
# # c.Filter_retweets = True



# #Pastikan sudah dalam bentuk csv
# c.Store_csv = True

# c.Output = "LocationJateng.csv"

# %%
c = twint.Config()

c.Search = "ibu kota negara"
c.Geo = "-6.932058, 107.608817, 120km"
c.Lang = "id"
c.Since = "2021-01-01"
c.Until = "2022-06-21"
# c.Filter_retweets = True



#Pastikan sudah dalam bentuk csv
c.Store_csv = True

c.Output = "LocationJabar.csv"

# %%
c = twint.Config()

c.Search = "ibu kota negara"
c.Geo = "-7.642600, 112.734730, 150km"
c.Lang = "id"
c.Since = "2021-01-01"
c.Until = "2022-06-21"
# c.Filter_retweets = True



#Pastikan sudah dalam bentuk csv
c.Store_csv = True

c.Output = "LocationJatim.csv"

# %% [markdown]
# Petunjuk terkait scraping:
# - Konfigurasi twint : https://github.com/twintproject/twint/wiki/Configuration
# - Query pencarian Twitter : https://github.com/igorbrigadir/twitter-advanced-search

# %%
c = twint.Config()

c.Search = "ibu kota negara"
c.Geo = "-6.218822, 106.843186, 15km"
c.Lang = "id"
c.Since = "2021-01-01"
c.Until = "2022-06-21"
# c.Filter_retweets = True



#Pastikan sudah dalam bentuk csv
c.Store_csv = True

c.Output = "LocationJakarta.csv"

# %%
c = twint.Config()

c.Search = "ibu kota negara"
c.Geo = "-8.026967, 110.347587, 35km"
c.Lang = "id"
c.Since = "2021-01-01"
c.Until = "2022-06-21"
# c.Filter_retweets = True



#Pastikan sudah dalam bentuk csv
c.Store_csv = True

c.Output = "LocationYog.csv"

# %%
c = twint.Config()

c.Search = "ibu kota negara"
c.Geo = "-8.026967, 110.347587, 35km"
c.Lang = "id"
c.Since = "2021-01-01"
c.Until = "2022-06-21"
# c.Filter_retweets = True



#Pastikan sudah dalam bentuk csv
c.Store_csv = True

c.Output = "LocationYog.csv"

# %%
c = twint.Config()

c.Search = "ibu kota negara"
c.Geo = "-8.026967, 110.347587, 50km"
c.Lang = "id"
c.Since = "2021-01-01"
c.Until = "2022-06-21"
# c.Filter_retweets = True



#Pastikan sudah dalam bentuk csv
c.Store_csv = True

c.Output = "LocationBanten.csv"

# %% [markdown]
# #### Twint, do your magic!!!

# %%
twint.run.Search(c)
# Out:
# 1535922271541665792 2022-06-12 09:49:40 +0000 <Mbahhardiman> @kumparan Dengan ketentuan partai politik anda mendukung pembangunan ibu kota negara di Kalimantan timur
# 1535921069697417216 2022-06-12 09:44:53 +0000 <Mbahhardiman> @kumparan Ibu kota negara Nusantara IKN di sebut ibu kota politik ya, otomatis mau tidak mau semua kantor pusat partai politik DPP partai politik di Kalimantan timur semua utk memudahkan kinerja perpolitikan Indonesia, para ketum parpol mau tidak mau patungan utk bangun DPP
# 1528535775499141120 2022-05-23 00:38:22 +0000 <Mbahhardiman> @OposisiCerdas Kalau 1 $US sama dengan 1000 silahkan bangun ibu kota negara baru perjuangkan dulu 1 dolar Amerika serikat setara 1000. Rakyat Indonesia tidak akan ribut soal pindah ibu kota negara Nusantara
# ...

# %%
import pandas as pd 
from google.colab import drive
drive.mount('/content/drive')
Jabar_path_csv = "/content/drive/Shareddrives/Kementerian Analisis Data Digital/DigiScope/5 IKN/code/persebaran lokasi/LocationJabar.csv"
Jateng_path_csv = "/content/drive/Shareddrives/Kementerian Analisis Data Digital/DigiScope/5 IKN/code/persebaran lokasi/LocationJateng.csv"
Banten_path_csv = "/content/drive/Shareddrives/Kementerian Analisis Data Digital/DigiScope/5 IKN/code/persebaran lokasi/LocationBanten.csv"
Jakarta_path_csv = "/content/drive/Shareddrives/Kementerian Analisis Data Digital/DigiScope/5 IKN/code/persebaran lokasi/LocationJakarta.csv"
Jatim_path_csv = "/content/drive/Shareddrives/Kementerian Analisis Data Digital/DigiScope/5 IKN/code/persebaran lokasi/LocationJatim.csv"
Yog_path_csv = "/content/drive/Shareddrives/Kementerian Analisis Data Digital/DigiScope/5 IKN/code/persebaran lokasi/LocationYog.csv"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Jabar_df = pd.read_csv(Jabar_path_csv)
Jateng_df = pd.read_csv(Jateng_path_csv)
Banten_df = pd.read_csv(Banten_path_csv)
Jakarta_df = pd.read_csv(Jakarta_path_csv)
Jatim_df = pd.read_csv(Jatim_path_csv)
Yog_df = pd.read_csv(Yog_path_csv)



# jawa tengah lat -7.155616 - -7.377748 , long 108.800032 - 111.130505

# %% [markdown]
# Melihat jumlah tweet

# %%
len(Jabar_df)
len(Jateng_df)
len(Banten_df)
len(Jakarta_df)
len(Jatim_df)
len(Yog_df)
